# %%
#%matplotlib notebook
import time, winsound, h5py
import numpy as np
import matplotlib.pyplot as plt
from lcls_beamline_toolbox.xraybeamline2d import beam1d as beam, optics1d as optics, beamline1d as beamline

# %% [markdown]
# ### Beam parameters

# %%
# number of sampling points
N = 2048
# photon energy in eV
E0 = 15275

# parameter dictionary. z_source is in LCLS coordinates (20 meters upstream of undulator exit)
beam_params = {
    'photonEnergy': E0,
    'N': N,
    'sigma_x': 23e-6,
    'sigma_y': 23e-6,
    'rangeFactor': 5,
    'scaleFactor': 10,
    'z_source': 630
}

# %%
def define_devices(
    f1, f2, slit_width = 500e-6, alphaAsym = np.deg2rad(34.35), E0=E0, f0 = 290., d23=7.):
    # crystal reflection hkl index
    hkl = [6,6,0]

    # viewing point upstream of monochromator
    im0 = optics.PPM('im0', z=870, FOV=2e-3, N=256)
    crl0 = optics.CRL('crl0', z=920, E0=E0, f=f0, diameter=2e-3)

    # first crystal: symmetric reflection
    crystal1 = optics.Crystal('c1', hkl=hkl, length=10e-2, width=20e-3, z=930, E0=E0,
                              alphaAsym=0, orientation=0, pol='s', delta=0.e-6)

    # second crystal: asymmetric reflection, orientation flipped relative to crystal1
    crystal2 = optics.Crystal('c2', hkl=hkl, length=10e-2, width=20e-3, z=crystal1.z+.2, E0=E0,alphaAsym=alphaAsym, 
                              orientation=2,pol='s', delta=0e-6)
    # printing crystal incidence and reflection angles for confirmation
    print('crystal 2 incidence angle: {:.2f} degrees'.format(crystal2.alpha*180/np.pi))
    print('crystal 2 exit angle: {:.2f} degrees'.format(crystal2.beta0*180/np.pi))

    im_upstream = optics.PPM('im_upstream', z=crystal2.z + f1 - .1, FOV=2e-3, N=256)

    # CRL with ~1 meter focal length (modeled as single element for now)
    crl1 = optics.CRL('crl1', z=crystal2.z+f1, E0=E0, f=f2, diameter=5e-3)

    # viewing point downstream of first crl
    im1 = optics.PPM('im1', z=crl1.z+.1,N=256,FOV=2e-3)

    # viewing point at focus
    focus = optics.PPM('focus', z=crl1.z+f2, FOV=100e-6, N=256)

    # slit at focus
    slit = optics.Slit('slit', z=crl1.z+f2 + 1e-3, x_width=slit_width, y_width=2e-3)

    # second CRL with ~1 meter focal length, for collimation
    crl2 = optics.CRL('crl2', z=crl1.z+2*f2, E0=E0, f=f2, diameter=5e-3)

    # third crystal, symmetric reflection, same orientation as crystal2
    crystal3 = optics.Crystal('c3', hkl=hkl, length=10e-2, width=10e-3, z=crl2.z+d23, E0=E0,alphaAsym=0, orientation=2,
                             asym_type='emergence',pol='s')

    # fourth crystal, asymmetric reflection, same orientation as crystal1
    crystal4 = optics.Crystal('c4', hkl=hkl, length=10e-2, width=10e-3, z=crl2.z+d23 + (f1-d23)*np.cos(crystal1.beta0*2), E0=E0,alphaAsym=-alphaAsym, 
                              asym_type='emergence', orientation=0,pol='s')

    # viewing point just downstream of monochromator
    im2 = optics.PPM('im2', z=crystal4.z+.1, FOV=2e-3, N=256)

    # list of devices to propagate through
    devices = [crl0,im0,crystal1,crystal2,im_upstream, im1, crl1, focus, slit, crl2, crystal3, crystal4, im2]

    return devices

# %% [markdown]
# ### Propagate central energy only (no time component) to tune lens roc

# %%
# initialize optical elements
f1 = 9.828256513026052
f2 = 10.

devices = define_devices(f1, f2)

# initialize beamline
mono_beamline = beamline.Beamline(devices)

for oe in devices:
    if oe.name == 'c1':
        print('crystal 1 incidence angle: {:.2f} degrees'.format(oe.alpha*180/np.pi))
        print('crystal 1 exit angle: {:.2f} degrees\n\n\n'.format(oe.beta0*180/np.pi))
        
# propagate
b1 = beam.Beam(beam_params=beam_params)
b2 = mono_beamline.propagate_beamline(b1)
# Out:
# b 1.00
# b 10.97
# crystal 2 incidence angle: 73.70 degrees
# crystal 2 exit angle: 5.02 degrees
# b 1.00
# b 0.09
# after c1: 1.3737
# after c2: -0.0003
# after c3: -1.3740
# after c4: -0.0003
# crystal 1 incidence angle: 39.35 degrees
# crystal 1 exit angle: 39.35 degrees
#
#
#
# FWHM in x: 38.3817560828058 microns
# FWHM in y: 38.3817560828058 microns
# FWHM Divergence (x): 1.3 μrad
# FWHM Divergence (y): 1.3 μrad
# 20.475529034937882
# 20.475529034937882
# x is focused
# y is focused
# FWHM in x: 319.2719441293782 microns
# FWHM in y: 319.2719441293782 microns
# FWHM Divergence (x): 1.3 μrad
# FWHM Divergence (y): 1.3 μrad
# 20.475529034937882
# 20.475529034937882
# x is focused
# y is focused
# im0
# zx: 240.000000
# zy: 240.000000
# azimuth 0.00 mrad
# drift1
# global_x 0.00
# global_y 0.00
# x intersect: 0.0000e+00
# component x: 0.0000e+00
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 294104122.88 microns
# zRy: 294104122.88 microns
# remaining distance: 50000000.00 microns
# goal for zx: 290000000.00 microns
# current zx: 240000000.00 microns
# goal for zy: 290000000.00 microns
# current zy: 240000000.00 microns
# zx: 290.000000
# zy: 290.000000
# azimuth 0.00 mrad
# crl0
# zRx: 1.80e+34
# zRy: 2.84e+02
# y becomes unfocused
# focal length: 290.00
# zx: -2305843009213693952.000000
# zy: 290.000000
# azimuth 0.00 mrad
# drift2
# global_x 0.00
# global_y 0.00
# x intersect: 0.0000e+00
# component x: 0.0000e+00
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 17965237826461140866682106444281754419200.00 microns
# zRy: 284164286.71 microns
# remaining distance: 10000000.00 microns
# goal for zx: -2305843009213693952000000.00 microns
# current zx: -2305843009213693952000000.00 microns
# goal for zy: 300000000.00 microns
# current zy: 290000000.00 microns
# current step size: 10000000.00 microns
# x remains focused
# y stays unfocused
# zx: -2305843009213693952.000000
# zy: 300.000000
# azimuth 0.00 mrad
# c1
# [ 1.11022302e-16  0.00000000e+00 -1.11022302e-16]
# Calculated distance to focus: 2305843009213693952.000000
# zRx: 1.80e+34
# zRy: 2.84e+02
# zx: -2305843008871470592.000000
# zy: 300.000000
# azimuth 1373.70 mrad
# drift3
# global_x 0.00
# global_y 0.00
# x intersect: 1.0016e+00
# component x: 1.0016e+00
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 17965237821128496540812800276902329712640.00 microns
# zRy: 284164286.71 microns
# remaining distance: 1021354.12 microns
# goal for zx: -2305843008871470689419264.00 microns
# current zx: -2305843008871470689419264.00 microns
# goal for zy: 301021354.12 microns
# current zy: 300000000.00 microns
# current step size: 1021354.12 microns
# x remains focused
# y stays unfocused
# zx: -2305843008871470592.000000
# zy: 301.021354
# azimuth 1373.70 mrad
# c2
# [ 3.80251386e-15  0.00000000e+00 -3.33066907e-16]
# Calculated distance to focus: 19170736021777836.000000
# zRx: 1.49e+32
# zRy: 2.84e+02
# zx: -19170736024232592.000000
# zy: 301.021354
# azimuth -0.30 mrad
# drift4
# global_x 1.00
# global_y 0.00
# x intersect: 9.9871e-01
# component x: 9.9871e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: -0.00
# zRx: 149362654179151803876758880667259895808.00 microns
# zRy: 284164286.71 microns
# remaining distance: 9700000.43 microns
# goal for zx: -19170736024232583495680.00 microns
# current zx: -19170736024232591884288.00 microns
# goal for zy: 310721354.55 microns
# current zy: 301021354.12 microns
# current step size: 9700000.43 microns
# x remains focused
# y stays unfocused
# zx: -19170736024232584.000000
# zy: 310.721355
# azimuth -0.30 mrad
# im_upstream
# zx: -19170736024232584.000000
# zy: 310.721355
# azimuth -0.30 mrad
# drift5
# global_x 1.00
# global_y 0.00
# x intersect: 9.9868e-01
# component x: 9.9868e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 149362654179151803876758880667259895808.00 microns
# zRy: 284164286.71 microns
# remaining distance: 100000.00 microns
# goal for zx: -19170736024232583495680.00 microns
# current zx: -19170736024232583495680.00 microns
# goal for zy: 310821354.55 microns
# current zy: 310721354.55 microns
# current step size: 100000.00 microns
# x remains focused
# y stays unfocused
# zx: -19170736024232584.000000
# zy: 310.821355
# azimuth -0.30 mrad
# crl1
# zRx: 4.06e+01
# zRy: 2.84e+02
# focal length: 10.00
# zx: -10.000000
# zy: 310.821355
# azimuth -0.30 mrad
# drift6
# global_x 1.00
# global_y 0.00
# x intersect: 9.9865e-01
# component x: 9.9865e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 40641005.87 microns
# zRy: 284164286.71 microns
# remaining distance: 100000.00 microns
# goal for zx: -9900000.00 microns
# current zx: -10000000.00 microns
# goal for zy: 310921354.56 microns
# current zy: 310821354.55 microns
# current step size: 100000.00 microns
# x remains focused
# y stays unfocused
# zx: -9.900000
# zy: 310.921355
# azimuth -0.30 mrad
# im1
# zx: -9.900000
# zy: 310.921355
# azimuth -0.30 mrad
# drift7
# global_x 1.00
# global_y 0.00
# x intersect: 9.9571e-01
# component x: 9.9571e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 40641005.87 microns
# zRy: 284164286.71 microns
# remaining distance: 9900000.43 microns
# goal for zx: 0.44 microns
# current zx: -9900000.00 microns
# goal for zy: 320821354.99 microns
# current zy: 310921354.56 microns
# current step size: 9900000.43 microns
# x remains focused
# y stays unfocused
# zx: 0.000000
# zy: 320.821355
# azimuth -0.30 mrad
# focus
# zx: 0.000000
# zy: 320.821355
# azimuth -0.30 mrad
# drift8
# global_x 1.00
# global_y 0.00
# x intersect: 9.9571e-01
# component x: 9.9571e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 40641005.87 microns
# zRy: 284164286.71 microns
# remaining distance: 1000.00 microns
# goal for zx: 1000.44 microns
# current zx: 0.44 microns
# goal for zy: 320822354.99 microns
# current zy: 320821354.99 microns
# current step size: 1000.00 microns
# x remains focused
# y stays unfocused
# zx: 0.001000
# zy: 320.822355
# azimuth -0.30 mrad
# slit
# zx: 0.001000
# zy: 320.822355
# azimuth -0.30 mrad
# drift9
# global_x 1.00
# global_y 0.00
# x intersect: 9.9275e-01
# component x: 9.9275e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 40641005.87 microns
# zRy: 284164286.71 microns
# remaining distance: 9999000.44 microns
# goal for zx: 10000000.88 microns
# current zx: 1000.44 microns
# goal for zy: 330821355.43 microns
# current zy: 320822354.99 microns
# current step size: 9999000.44 microns
# x remains focused
# y stays unfocused
# zx: 10.000001
# zy: 330.821355
# azimuth -0.30 mrad
# crl2
# zRx: 5.27e+15
# zRy: 2.84e+02
# focal length: 10.00
# zx: -113924287.965518
# zy: 330.821355
# azimuth -0.30 mrad
# drift10
# global_x 0.99
# global_y 0.00
# x intersect: 9.9068e-01
# component x: 9.9068e-01
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: -0.00
# zRx: 5274691861795245654016.00 microns
# zRy: 284164286.71 microns
# remaining distance: 7000000.31 microns
# goal for zx: -113924280965517.22 microns
# current zx: -113924287965517.53 microns
# goal for zy: 337821355.74 microns
# current zy: 330821355.43 microns
# current step size: 7000000.31 microns
# x remains focused
# y stays unfocused
# zx: -113924280.965517
# zy: 337.821356
# azimuth -0.30 mrad
# c3
# [ 2.77555756e-15  0.00000000e+00 -2.33146835e-15]
# Calculated distance to focus: 113924280.965517
# zRx: 5.27e+15
# zRy: 2.84e+02
# zx: -113925992.295581
# zy: 337.821356
# azimuth -1374.00 mrad
# drift11
# global_x 0.99
# global_y 0.00
# x intersect: -1.7594e+00
# component x: -1.7594e+00
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: -0.00
# zRx: 5274849683859697565696.00 microns
# zRy: 284164286.71 microns
# remaining distance: 2804160.67 microns
# goal for zx: -113925989491420.09 microns
# current zx: -113925992295580.77 microns
# goal for zy: 340625516.41 microns
# current zy: 337821355.74 microns
# current step size: 2804160.67 microns
# x remains focused
# y stays unfocused
# zx: -113925989.491420
# zy: 340.625516
# azimuth -1374.00 mrad
# c4
# [ 0.00000000e+00  0.00000000e+00 -2.22044605e-16]
# Calculated distance to focus: 13789541893.900274
# zRx: 6.38e+17
# zRy: 2.84e+02
# zx: -13788306128.512827
# zy: 340.625516
# azimuth -0.30 mrad
# drift12
# global_x -1.76
# global_y 0.00
# x intersect: -1.7594e+00
# component x: -1.7594e+00
# y intersect: 0.0000e+00
# component y: 0.0000e+00
# delta z: 0.00
# zRx: 638350573692860269330432.00 microns
# zRy: 284164286.71 microns
# remaining distance: 100000.00 microns
# goal for zx: -13788306128412826.00 microns
# current zx: -13788306128512826.00 microns
# goal for zy: 340725516.42 microns
# current zy: 340625516.41 microns
# current step size: 100000.00 microns
# x remains focused
# y stays unfocused
# zx: -13788306128.412827
# zy: 340.725516
# azimuth -0.30 mrad
# im2
# zx: -13788306128.412827
# zy: 340.725516
# azimuth -0.30 mrad
# C:\Users\nanw0\Anaconda3\envs\lcls\lib\site-packages\scipy\optimize\minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %% [markdown]
# ### Propagate energy components and plot beam profiles

# %%
# %%capture capt
tstart = time.time()
# propagate
beam_params['photonEnergy'] = E0
pulse = beam.Pulse(beam_params=beam_params, tau=400, time_window=10000)
pulse.propagate(beamline=mono_beamline, screen_names=['focus','im2'])
tfin = time.time()

# %% [raw]
# ''' energy slices '''
# pulse.imshow_energy_slice('focus')
# pulse.imshow_energy_slice('im2')

# %% [raw]
# ''' spatial projection (x,y)'''
# pulse.imshow_projection('focus')
# pulse.imshow_projection('im2')

# %%
''' time slice '''
print('total {}s, per slice {}ms'.format(round(tfin-tstart,2), round(1000*(tfin-tstart)/pulse.N,2)))

shift = 0
pulse.imshow_time_slice('focus', shift = shift)
pulse.imshow_time_slice('im2', shift = shift)
pulse.plot_pulse('im2', shift = shift)

#for i in range(2):
#    winsound.Beep(1000,1000)
# Out:
# total 4.59s, per slice 82.05ms

# %% [raw]
# %%capture capt
# # loop through f1 and see what time profile looks like
# f1_list = np.linspace(-0.2,0.2,50) + 9.8
# for f1 in f1_list:
#     devices = define_devices(f1, f2)
#     mono_beamline = beamline.Beamline(devices)
#     beam_params['photonEnergy'] = E0
#     pulse = beam.Pulse(beam_params=beam_params, tau=400, time_window=150000)
#     pulse.propagate(beamline=mono_beamline, screen_names=['im2'])
#     pulse.imshow_time_slice('im2')
#     plt.savefig(fig_path+'time_profile_f1={}.png'.format(f1))
# for i in range(2):
#     winsound.Beep(1000,1000)

# %% [markdown]
# ### Optimization

# %%
# %%capture capt
tstart = time.time()
NN = 500
f1 = np.linspace(9.8, 9.85, NN)

duration = np.zeros(NN)

for i, f in enumerate(f1):
    devices = define_devices(f, 10)
    # initialize beamline
    mono_beamline = beamline.Beamline(devices)
    # reset central photon energy
    beam_params['photonEnergy'] = E0

    # initialize pulse. tau sets transform-limited pulse duration in fs (FWHM). Time window is in fs.
    pulse = beam.Pulse(beam_params=beam_params, tau=400, time_window=10000)

    print('Number of spectral components: {:d}'.format(pulse.N))
    pulse.propagate(beamline=mono_beamline, screen_names=['im2'])
    centroid, duration[i] = pulse.pulse_duration('im2')
tfin = time.time()

# %%
fig_path = "C:/Users/nanw0/GoogleDrive/SLAC/SLAC-Diling/9. 20 Summer/Hasan Mono Analysis/Matt's_Plots/"
hkl = devices[2].hkl
hkl = int(hkl[0]*100+hkl[1]*10+hkl[2])
fname = 'pulse_duration_{}_{}keV'.format(
    hkl, round(beam_params['photonEnergy']/1000.,4))

with h5py.File(fig_path+fname+'.h5','w') as f:
    f.create_dataset('f1', data=f1)
    f.create_dataset('duration', data=duration)

# %%
# plot range
f1_min = f1.min()
f1_max = f1.max()
ii = np.argwhere(f1>=f1_min).min()
ifin = np.argwhere(f1<=f1_max).max()

plt.figure()
plt.plot(f1[ii:ifin], np.abs(duration[ii:ifin]))
plt.xlabel('Crystal to lens distance (m)')
plt.ylabel('Pulse duration (fs)')
# plt.ylim(0,200)
plt.grid()
f1_opt = f1[ii:ifin][np.argmin(duration[ii:ifin])]
plt.title(f1_opt)
plt.savefig(fig_path+fname+'_{}-{}m.png'.format(round(f1_min,2), round(f1_max,2)))

print(f1_opt)
# Out:
# 9.828256513026052

# %%
for i in range(2):
    winsound.Beep(1000,1000)
